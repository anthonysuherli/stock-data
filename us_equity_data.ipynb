# %%
# !pip install simfin #just run this once

# %%
import simfin as sf

#collect data from api
sf.set_api_key('PLEbHyzQgm98TrvHFejzBwikq1mKiJob ')
sf.set_data_dir('~/simfin_data/')

figures_and_ratios = sf.load_derived(variant = 'quarterly',market = 'us',refresh_days = 1)
sector_industry = sf.load_industries(refresh_days = 1)
balance_sheet = sf.load_balance(variant='quarterly-full', market='us',refresh_days = 1)
companies = sf.load_companies(market='us',refresh_days = 1)
cash_flow = sf.load_cashflow(variant='quarterly-full', market='us',refresh_days = 1)
income_statement = sf.load_income(variant='quarterly-full', market='us',refresh_days = 1)
historical_prices = sf.load_shareprices(variant = 'daily', market = 'us',refresh_days = 1)
price_ratios = sf.load_derived_shareprices(variant='daily', market='us',refresh_days = 1)
# Out:
# ...
# Dataset "us-derived-quarterly" on disk (18 days old).
# - Downloading ... 100.0%
# - Extracting zip-file ... Done!
# - Loading from disk ... Done!
# Dataset "industries" on disk (18 days old).
# - Downloading ... 100.0%
# - Extracting zip-file ... Done!
# - Loading from disk ... Done!
# Dataset "us-balance-quarterly-full" not on disk.
# - Downloading ... 100.0%
# - Extracting zip-file ... Done!
# - Loading from disk ... Done!
# Dataset "us-companies" on disk (18 days old).
# - Downloading ... 100.0%
# - Extracting zip-file ... Done!
# - Loading from disk ... Done!
# Dataset "us-cashflow-quarterly-full" not on disk.
# - Downloading ... 100.0%
# - Extracting zip-file ... Done!
# - Loading from disk ... Done!
# Dataset "us-income-quarterly-full" not on disk.
# - Downloading ... 100.0%
# - Extracting zip-file ... Done!
# - Loading from disk ... Done!
# Dataset "us-shareprices-daily" on disk (18 days old).
# - Downloading ... 50.7%
# IOPub message rate exceeded.
# ...

# %%
figures_and_ratios
# Out:
#                     SimFinId Currency  Fiscal Year Fiscal Period Publish Date  \
# Ticker Report Date
# A      2010-07-31      45846      USD         2010            Q3   2010-09-07
#        2010-10-31      45846      USD         2010            Q4   2010-12-08
#        2011-01-31      45846      USD         2011            Q1   2011-03-09
#        2011-04-30      45846      USD         2011            Q2   2011-06-07
#        2011-07-31      45846      USD         2011            Q3   2011-09-07
# ...                      ...      ...          ...           ...          ...
# ZYXI   2019-09-30     171401      USD         2019            Q3   2019-10-29
#        2019-12-31     171401      USD         2019            Q4   2020-02-27
#        2020-03-31     171401      USD         2020            Q1   2020-04-28
#        2020-06-30     171401      USD         2020            Q2   2020-07-28
#        2020-09-30     171401      USD         2020            Q3   2020-10-27
#
# ...
